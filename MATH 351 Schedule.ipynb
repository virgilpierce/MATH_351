# %%
import pandas as pa
import datetime as dt
pa.set_option('max_colwidth', 200)

# %%
first_day = dt.date(2019, 8, 27)

# %%
holidays = [dt.date(2019, 9, 2) ]
thanksgiving_start = dt.date(2019, 11, 27)
thanksgiving_end = dt.date(2019, 12, 1)
thanksgiving_delta = thanksgiving_end - thanksgiving_start
holidays += [thanksgiving_start + dt.timedelta(i) for i in range(thanksgiving_delta.days+1)]

# %%
last_day = dt.date(2019, 12, 5)

# %%
final_exam = dt.date(2019, 12, 11)

# %%
semester_length = last_day - first_day

# %%
class_days = []
for i in range((semester_length.days //7 + 1)):
    class_days += [first_day + dt.timedelta(i*7), first_day + dt.timedelta(i*7+2)]
class_days += [final_exam]

# %%
schedule = pa.DataFrame(class_days, columns = ['Day'])
weekday_dict = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
for i in range(schedule.shape[0]):
    schedule.loc[i,'Week_Day'] = schedule.loc[i, 'Day'].weekday()
schedule.Week_Day = schedule.Week_Day.map(weekday_dict)

# %%
for holiday in holidays:
    schedule.loc[schedule.Day==holiday, 'Title'] = 'No Class - University Holiday'

# %%
def add_day(title='', description='', notes=''):
    global schedule
    global day
    
    while schedule.loc[day, 'Day'] in holidays:
        day += 1
    if day >= schedule.shape[0]:
        print('Error to many days')
        return 'ERROR'
    else:
        schedule.loc[day, 'Title'] = title
        schedule.loc[day, 'Description'] = description
        schedule.loc[day, 'Notes'] = notes
        
        day += 1

# %%
day = 0

add_day('Course Introduction', 'What is Data Science?')

add_day('Motivating Examples', 'What kinds of questions can we ask?')

add_day('Data', 'What is data, where to get it?')

add_day('Team - Forming Teams', 'Deciding how we will divide up into teams', 'Team Day 1')

add_day('Tools of the Trade', 'Python / Jupyter Basics, Importing and Exporting Data,'+\
                       'Development and Version Control')

add_day('The Data Science Process', 'Controlling for Error, Professional ethics')

add_day('Team - Proposal', "Developing your team's proposal", 'Team Day 2')

add_day('Wrangling the Data and Cross Validation', 'Formatting data and dealing with data types,'+\
        'Techniques for Cross Validation')

add_day('Exploratory Data Analysis', 'Plots with seaborn, summary statistics, background '+\
                        'on linear regression', 'Linear regression is our first model')

add_day('Principal Component Analysis', 'Singular value decomposition and principal component analysis', 
       'The most important fact from Linear Algebra')

add_day('Statistical Learning and Models', 'Review of the Data Science workflow, '+\
                       'boostrapping our data, building our model - linear regression, testing our model')

add_day('Team - Wrangling and Exploring YOUR Data', "Taking a look at the team's data - identifying and dealing "+\
        'with issues, looking at plots', 'Team Day 3')

add_day('K-Nearest Neighbors', 'K-Nearest Neighbors for regression and categorization', 
                       'Building the actual model, plotting and testing the results.')

add_day('Team - K-Nearest Neighbors', 'Building K-Nearest Neighbors for your data', 'Team Day 4')

add_day('A Zoo of Models for Regression', 'Nonlinear regression, Ridge, and Lasso Methods', 
                       'Different types of errors and plotting results')

add_day('A Zoo of Models for Categorization - 1', 'Linear Discriminant Analysis, Support Vector Machines')

add_day('Team - Modeling your data - 1', 'Digging Deeper into modeling your data', 'Team Day 5')

add_day('A Zoo of Models for Cateogrization - 2', 'Decision Trees, and exploring lots of examples')


add_day('Team - Modeling your data - 2', 'Digging Deeper into modeling your data', 'Team Day 6')

add_day('Team - Presentations - A', 'Preliminary Reports and Presentations from the teams', 'Team Day 7')

add_day('Ensembles of Models, and Neural Networks', 'Avoiding overfitting and advanced ideas')

add_day('Team - Modeling your data - 3', 'Digging Deeper still into modeling your data', 'Team Day 8')

add_day('Unsupeervised Learning', 'Examples of unsupervised learning')

add_day('Team - Modeling your data - 4', 'Digging Deeper still into modeling your data', 'Team Day 9')

add_day('Advanced Topics - 1', 'Spatial Data')

add_day('Team - Preparing Reports', 'Putting it all together', 'Team Day 10')

add_day('Advanced Topics - 2', 'Text Mining and AI')

add_day('Team - Preparing Reports', 'Putting it all together', 'Team Day 11')

add_day('Advanced Topics - 3', 'Big data, big iron, and parallel processing')

add_day('Team - Final Presentations', '8am - 10:30am', '35 minutes per team + 15 minutes for questions')

schedule
# Out:
#            Day   Week_Day                                     Title  \
# 0   2019-08-27    Tuesday                       Course Introduction
# 1   2019-08-29   Thursday                       Motivating Examples
# 2   2019-09-03    Tuesday                                      Data
# 3   2019-09-05   Thursday                      Team - Forming Teams
# 4   2019-09-10    Tuesday                        Tools of the Trade
# 5   2019-09-12   Thursday                  The Data Science Process
# 6   2019-09-17    Tuesday                           Team - Proposal
# 7   2019-09-19   Thursday   Wrangling the Data and Cross Validation
# 8   2019-09-24    Tuesday                 Exploratory Data Analysis
# 9   2019-09-26   Thursday              Principal Component Analysis
# 10  2019-10-01    Tuesday           Statistical Learning and Models
# 11  2019-10-03   Thursday  Team - Wrangling and Exploring YOUR Data
# 12  2019-10-08    Tuesday                       K-Nearest Neighbors
# 13  2019-10-10   Thursday                Team - K-Nearest Neighbors
# 14  2019-10-15    Tuesday            A Zoo of Models for Regression
# 15  2019-10-17   Thursday    A Zoo of Models for Categorization - 1
# 16  2019-10-22    Tuesday             Team - Modeling your data - 1
# 17  2019-10-24   Thursday    A Zoo of Models for Cateogrization - 2
# 18  2019-10-29    Tuesday             Team - Modeling your data - 2
# 19  2019-10-31   Thursday                  Team - Presentations - A
# 20  2019-11-05    Tuesday  Ensembles of Models, and Neural Networks
# 21  2019-11-07   Thursday             Team - Modeling your data - 3
# 22  2019-11-12    Tuesday                    Unsupeervised Learning
# 23  2019-11-14   Thursday             Team - Modeling your data - 4
# 24  2019-11-19    Tuesday                       Advanced Topics - 1
# 25  2019-11-21   Thursday                  Team - Preparing Reports
# 26  2019-11-26    Tuesday                       Advanced Topics - 2
# 27  2019-11-28   Thursday             No Class - University Holiday
# 28  2019-12-03    Tuesday                  Team - Preparing Reports
# 29  2019-12-05   Thursday                       Advanced Topics - 3
# 30  2019-12-11  Wednesday                Team - Final Presentations
#
#                                                                                                               Description  \
# 0                                                                                                   What is Data Science?
# 1                                                                                     What kinds of questions can we ask?
# 2                                                                                          What is data, where to get it?
# 3                                                                               Deciding how we will divide up into teams
# 4                                   Python / Jupyter Basics, Importing and Exporting Data,Development and Version Control
# 5                                                                              Controlling for Error, Professional ethics
# 6                                                                                         Developing your team's proposal
# 7                                             Formatting data and dealing with data types,Techniques for Cross Validation
# 8                                                 Plots with seaborn, summary statistics, background on linear regression
# 9                                                           Singular value decomposition and principal component analysis
# 10  Review of the Data Science workflow, boostrapping our data, building our model - linear regression, testing our model
# 11                               Taking a look at the team's data - identifying and dealing with issues, looking at plots
# 12                                                                  K-Nearest Neighbors for regression and categorization
# 13                                                                             Building K-Nearest Neighbors for your data
# 14                                                                         Nonlinear regression, Ridge, and Lasso Methods
# 15                                                                  Linear Discriminant Analysis, Support Vector Machines
# 16                                                                                 Digging Deeper into modeling your data
# 17                                                                         Decision Trees, and exploring lots of examples
# 18                                                                                 Digging Deeper into modeling your data
# 19                                                                   Preliminary Reports and Presentations from the teams
# 20                                                                                Avoiding overfitting and advanced ideas
# 21                                                                           Digging Deeper still into modeling your data
# 22                                                                                      Examples of unsupervised learning
# 23                                                                           Digging Deeper still into modeling your data
# 24                                                                                                           Spatial Data
# 25                                                                                                Putting it all together
# 26                                                                                                     Text Mining and AI
# 27                                                                                                                    NaN
# 28                                                                                                Putting it all together
# 29                                                                            Big data, big iron, and parallel processing
# 30                                                                                                          8am - 10:30am
#
#                                                            Notes
# 0
# 1
# 2
# 3                                                     Team Day 1
# 4
# 5
# 6                                                     Team Day 2
# 7
# 8                           Linear regression is our first model
# 9                    The most important fact from Linear Algebra
# 10
# 11                                                    Team Day 3
# 12  Building the actual model, plotting and testing the results.
# 13                                                    Team Day 4
# 14                Different types of errors and plotting results
# 15
# 16                                                    Team Day 5
# 17
# 18                                                    Team Day 6
# 19                                                    Team Day 7
# 20
# 21                                                    Team Day 8
# 22
# 23                                                    Team Day 9
# 24
# 25                                                   Team Day 10
# 26
# 27                                                           NaN
# 28                                                   Team Day 11
# 29
# 30                35 minutes per team + 15 minutes for questions
